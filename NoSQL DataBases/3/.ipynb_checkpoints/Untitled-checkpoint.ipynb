# %%
from pymongo import MongoClient, ASCENDING, DESCENDING
import pprint

host = 'ec2-54-67-15-68.us-west-1.compute.amazonaws.com'
client = MongoClient(host, 9210)

# %%
db = client.nosql
db_names = db.list_collection_names()
pprint.pprint(db_names)
# Out:
# ['population']

# %%
db
# Out:
# Database(MongoClient(host=['ec2-54-67-15-68.us-west-1.compute.amazonaws.com:9210'], document_class=dict, tz_aware=False, connect=True), 'nosql')

# %%
from pymongo import MongoClient, ASCENDING, DESCENDING
import pprint

host = 'ec2-54-67-15-68.us-west-1.compute.amazonaws.com'
client = MongoClient(host, 9210)
db = client.nosql
db_names = db.list_collection_names()
pprint.pprint(db_names)

population_item = {'city':'Cupertino', 'zipcodes':[95014, 95015], 'county': 'Santa Clara', 'state':'CA', 'population':50000};
population = db.population
population_id = population.insert_one(population_item).inserted_id
print(population_id)

population.update_one({'city':'Cupertino'}, {'$set':{'population':60000} })
population.delete_one({'city':'Cupertino'})
population.delete_one({'_id':population_id})

population_items = [
	{'city':'Santa Clara', 'zipcodes':[95050, 95051, 95052, 95053, 95054, 95055, 95056], 'county': 'Santa Clara', 'state':'CA', 'population':100000},	
	{'city':'Sunnyvale', 'zipcodes':[94085, 94086, 94087, 94088, 94089], 'county': 'Santa Clara', 'state':'CA', 'population':150000},	
	{'city':'Mountain View', 'zipcodes':[94035, 94039, 94040, 94041, 94042, 94043], 'county': 'Santa Clara', 'state':'CA', 'population':120000}
]
population_ids = population.insert_many(population_items)

print(population_ids.inserted_ids)

population_document = population.find_one({'city':'Cupertino'})
print('Find one document')
pprint.pprint(population_document)

population_documents = population.find({'city': {'$in':['Cupertino', 'Santa Clara']} })
print('Total count of documents = ', population.estimated_document_count())

for item in population_documents:
  pprint.pprint(item)

for index in population.list_indexes():
  pprint.pprint(index)

population.create_index([('city', ASCENDING)])

print('Created Index')
pprint.pprint(population.index_information())

population.drop_index('city_1')

print('Dropped Index')
pprint.pprint(population.index_information())
# Out:
# ['population']
# 5b9092f015377668030fb36f
# [ObjectId('5b9092f015377668030fb370'), ObjectId('5b9092f015377668030fb371'), ObjectId('5b9092f015377668030fb372')]
# Find one document
# {'_id': ObjectId('5b8d895c7e386a528ccfbe1e'),
#  'city': 'Cupertino',
#  'population': 50000}
# Total count of documents =  62
# {'_id': ObjectId('5b8d87447e386a48bee57c3c'),
#  'city': 'Santa Clara',
#  'population': 100000}
# {'_id': ObjectId('5b8d874e7e386a48ed778908'),
#  'city': 'Santa Clara',
#  'population': 100000}
# {'_id': ObjectId('5b8d87af7e386a4aa9f22612'),
#  'city': 'Santa Clara',
#  'population': 100000}
# {'_id': ObjectId('5b8d87eb7e386a4ba03fbbb1'),
#  'city': 'Santa Clara',
#  'population': 100000}
# {'_id': ObjectId('5b8d88637e386a4dc7079a98'),
#  'city': 'Santa Clara',
#  'population': 100000}
# {'_id': ObjectId('5b8d895c7e386a528ccfbe1e'),
#  'city': 'Cupertino',
#  'population': 50000}
# {'_id': ObjectId('5b8d895c7e386a528ccfbe1f'),
#  'city': 'Santa Clara',
#  'population': 100000}
# {'_id': ObjectId('5b8d949f7e386a60847c03f1'),
#  'city': 'Cupertino',
#  'population': 50000,
#  'zipcodes': [95014, 95015]}
# {'_id': ObjectId('5b8d949f7e386a60847c03f2'),
#  'city': 'Santa Clara',
#  'population': 100000}
# {'_id': ObjectId('5b8d97717e386a6cfbea2062'),
#  'city': 'Cupertino',
#  'county': 'Santa Clara',
#  'population': 50000,
#  'state': 'CA',
#  'zipcodes': [95014, 95015]}
# {'_id': ObjectId('5b8d97717e386a6cfbea2063'),
#  'city': 'Santa Clara',
#  'county': 'Santa Clara',
#  'population': 100000,
#  'state': 'CA',
#  'zipcodes': [95050, 95051, 95052, 95053, 95054, 95055, 95056]}
# {'_id': ObjectId('5b8d983d7e386a708a93640a'),
#  'city': 'Cupertino',
#  'county': 'Santa Clara',
#  'population': 50000,
#  'state': 'CA',
#  'zipcodes': [95014, 95015]}
# {'_id': ObjectId('5b8d983d7e386a708a93640b'),
#  'city': 'Santa Clara',
#  'county': 'Santa Clara',
#  'population': 100000,
#  'state': 'CA',
#  'zipcodes': [95050, 95051, 95052, 95053, 95054, 95055, 95056]}
# {'_id': ObjectId('5b8dd1cc7e386a2b572b7296'),
#  'city': 'Cupertino',
#  'county': 'Santa Clara',
#  'population': 50000,
#  'state': 'CA',
#  'zipcodes': [95014, 95015]}
# {'_id': ObjectId('5b8dd1e87e386a2be7f03d1b'),
#  'city': 'Santa Clara',
#  'county': 'Santa Clara',
#  'population': 100000,
#  'state': 'CA',
#  'zipcodes': [95050, 95051, 95052, 95053, 95054, 95055, 95056]}
# {'_id': ObjectId('5b9090e38fc8f21fae9114e3'),
#  'city': 'Santa Clara',
#  'county': 'Santa Clara',
#  'population': 100000,
#  'state': 'CA',
#  'zipcodes': [95050, 95051, 95052, 95053, 95054, 95055, 95056]}
# {'_id': ObjectId('5b9090eab7175148a041ee6d'),
#  'city': 'Santa Clara',
#  'county': 'Santa Clara',
#  'population': 100000,
#  'state': 'CA',
#  'zipcodes': [95050, 95051, 95052, 95053, 95054, 95055, 95056]}
# {'_id': ObjectId('5b90918702360115a80cc0e5'),
#  'city': 'Santa Clara',
#  'county': 'Santa Clara',
#  'population': 100000,
#  'state': 'CA',
#  'zipcodes': [95050, 95051, 95052, 95053, 95054, 95055, 95056]}
# {'_id': ObjectId('5b90918ab7175148a041ee72'),
#  'city': 'Santa Clara',
#  'county': 'Santa Clara',
#  'population': 100000,
#  'state': 'CA',
#  'zipcodes': [95050, 95051, 95052, 95053, 95054, 95055, 95056]}
# {'_id': ObjectId('5b9091f11ef82b20340b4a47'),
#  'city': 'Santa Clara',
#  'county': 'Santa Clara',
#  'population': 100000,
#  'state': 'CA',
#  'zipcodes': [95050, 95051, 95052, 95053, 95054, 95055, 95056]}
# {'_id': ObjectId('5b9092184456983d54983032'),
#  'city': 'Santa Clara',
#  'county': 'Santa Clara',
#  'population': 100000,
#  'state': 'CA',
#  'zipcodes': [95050, 95051, 95052, 95053, 95054, 95055, 95056]}
# {'_id': ObjectId('5b9092a2b7175148a041ee77'),
#  'city': 'Santa Clara',
#  'county': 'Santa Clara',
#  'population': 100000,
#  'state': 'CA',
#  'zipcodes': [95050, 95051, 95052, 95053, 95054, 95055, 95056]}
# {'_id': ObjectId('5b9092ce7f0e70165f35da8e'),
#  'city': 'Santa Clara',
#  'county': 'Santa Clara',
#  'population': 100000,
#  'state': 'CA',
#  'zipcodes': [95050, 95051, 95052, 95053, 95054, 95055, 95056]}
# {'_id': ObjectId('5b9092f015377668030fb370'),
#  'city': 'Santa Clara',
#  'county': 'Santa Clara',
#  'population': 100000,
#  'state': 'CA',
#  'zipcodes': [95050, 95051, 95052, 95053, 95054, 95055, 95056]}
# {'key': SON([('_id', 1)]),
#  'name': '_id_',
#  'ns': 'nosql.population',
#  'v': 2}
# Created Index
# {'_id_': {'key': [('_id', 1)], 'ns': 'nosql.population', 'v': 2},
#  'city_1': {'key': [('city', 1)], 'ns': 'nosql.population', 'v': 2}}
# Dropped Index
# {'_id_': {'key': [('_id', 1)], 'ns': 'nosql.population', 'v': 2}}

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# /Users/satah/anaconda3/lib/python3.6/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)
# WARNING: AstropyDeprecationWarning: The astropy.vo.samp module has now been moved to astropy.samp [astropy.vo.samp]
# WARNING: Logging before flag parsing goes to stderr.
# W0906 16:14:43.155977 140735675937664 logger.py:220] AstropyDeprecationWarning: The astropy.vo.samp module has now been moved to astropy.samp
# /Users/satah/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /Users/satah/anaconda3/lib/python3.6/site-packages/odo/backends/pandas.py:102: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access NaTType as type(pandas.NaT)
#   @convert.register((pd.Timestamp, pd.Timedelta), (pd.tslib.NaTType, type(None)))
# Using TensorFlow backend.
# /Users/satah/anaconda3/lib/python3.6/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "
# /Users/satah/anaconda3/lib/python3.6/site-packages/skimage/viewer/utils/core.py:10: UserWarning: Recommended matplotlib backend is `Agg` for full skimage.viewer functionality.
#   warn("Recommended matplotlib backend is `Agg` for full "
# /Users/satah/anaconda3/lib/python3.6/site-packages/qtawesome/iconic_font.py:268: UserWarning: You need to have a running QApplication to use QtAwesome!
#   warnings.warn("You need to have a running "
# /Users/satah/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
