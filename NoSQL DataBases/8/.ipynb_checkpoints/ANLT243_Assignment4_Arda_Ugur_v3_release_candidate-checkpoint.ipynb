# %% [markdown]
# ## ANLT-243 - NoSQL DATABASES
# ## ASSIGNMENT #4 - ANALYSIS of HIGGS BOSON PARTICLE TWEETS - Neo4j

# %% [markdown]
# __by Arda Ugur__<br>
# <a_ugur1@u.pacific.edu>
# <br><br/>
# __University of the Pacific, School of Engineering and Computer Science<br />
# Data Science Graduate Program__<br><br>
# __September 2018__

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem Definition:

# %% [markdown]
# The Higgs dataset has been built after monitoring the spreading processes on Twitter before, during and after the announcement of the discovery of a new particle with the features of the elusive __Higgs Boson__ on 4th July 2012.
# <br><br>
# Here are the summary statistics on the twitter data as shown in the web site (http://snap.stanford.edu/data/higgs-twitter.htmlLinks)
# <br><br>
# __Social Network statistics:__<br>
# <br>
# Nodes    456626<br>
# Edges    14855842<br>
# <br>
# __Retweet Network statistics:__<br>
# <br>
# Nodes    256491<br>
# Edges    328132<br>
# <br>
# __Reply Network statistics:__<br>
# <br>
# Nodes    38918<br>
# Edges    32523<br>
# <br>
# __Mention Network statistics:__<br>
# <br>
# Nodes    116408<br>
# Edges    150818<br>
# <br><br>
# Higgs Boson Twitter data is published in the __Neo4j__ database deployed with the following configuration:<br>
# <br>
# __
# host = 'ec2-54-67-15-68.us-west-1.compute.amazonaws.com'<br>
# port = '9232'<br>
# __
#
# The nodes use the label __"User"__
#
# The four relationship edges use the following _Labels_:
#
# Followers Social Network edge label  __"Follows"__
#
# Retweet Network edge label __"Retweets"__
#
# Reply Network edge label __"Replys"__
#
# Mention Network edge label __"Mentions"__
# <br><br>
#
# Based on the information given above, answer the following questions using __Neo4J Graph queries__. For the first three questions, use the provided queries and perform Neo4j query transactions and print your results. For the rest of the questions, build your own queries to print the answers.
#
# 1. How many total nodes with Label :User are there in the database?
#
#     match (:User) return count(*) as User_Count<br>
# <br>
# 2. How many Social Network relationships are there in the database?
#
#     match ()-[follows:Follows]->() return count(follows)<br>
# <br>
# 3. How many Social Network followers does user 89805 have?
#
#     match (follower)-[:Follows]->(:User{user:89805}) return count(follower)<br>
# <br>
# 4. How many total times did users in this network retweet?<br>
# <br>
# 5. How many times did users in this network reply to other user's tweets?<br>
# <br>
# 6. How many times did users in this network mention other users in their tweets?<br>
# <br>
# 7. How many users follow user 89805?<br>
# <br>
# 8. How many users does user 89805 follow?<br>
# <br>
# 9. Did user 14907 ever retweet user 89805?<br>
# <br>
# 10. Did user 89805 ever retweet user 14907?<br>
# <br>
# 11. Find out the top 5 users with the highest number of followers?<br>
# <br>
# 12. What is the total count of followers of followers of user 89805?<br>
#
#
# __References:__
#
# Here is a good Neo4j reference on the __Cypher__ language. You can use it to learn simple and advanced queries and operations on Neo4j.
#
# https://neo4j.com/docs/cypher-refcard/current/Links

# %% [markdown]
# ## Solution

# %% [markdown]
# ### 0. Configuration

# %%
# Graph DB Config
#
from neo4j.v1 import GraphDatabase

# %%
# Remote Database Connection
# 
host = 'ec2-54-67-15-68.us-west-1.compute.amazonaws.com'
port = '9232'

# %%
# Remote Database Access
#
uri = "bolt://" + host + ':' + port
#
driver = GraphDatabase.driver(uri, auth=("neo4j", "password"), encrypted=False)
session = driver.session()

# %% [markdown]
# ### 1. How many total nodes with Label :User are there in the database?

# %%
# Question 1:
# How many total nodes with Label :User are there in the database?
#
# We are using the provided code
#
with session.begin_transaction() as higgsboson:
    for i in higgsboson.run('match(:User) return count(*) as User_Count'):
        print(i)
# Out:
# <Record User_Count=456626>

# %% [markdown]
# ### 2. How many Social Network relationships are there in the database?

# %%
# Question 2:
# How many Social Network relationships are there in the database?
#
# We are using the provided code
#
with session.begin_transaction() as higgsboson:
    for i in higgsboson.run('match ()-[follows:Follows]->() return count(follows)'):
        print(i)
# Out:
# <Record count(follows)=14855842>

# %% [markdown]
# ### 3. How many Social Network followers does user 89805 have?

# %%
# Question 3: 
# How many Social Network followers does user 89805 have?
#
# We are using the provided code
#
with session.begin_transaction() as higgsboson:
    for i in higgsboson.run('match (follower)-[:Follows]->(:User{user:89805}) return count(follower)'):
        print(i)
# Out:
# <Record count(follower)=156>

# %% [markdown]
# ### 4. How many total times did users in this network retweet?

# %%
# Question 4:
# How many total times did users in this network retweet?
#
with session.begin_transaction() as higgsboson:
    for i in higgsboson.run('match ()-[retweets:Retweets]->() return count(retweets)'):
        print(i)
# Out:
# <Record count(retweets)=328132>

# %% [markdown]
# ### 5. How many times did users in this network reply to other user's tweets?

# %%
# Question 5:
# How many times did users in this network reply to other user's tweets?
#
with session.begin_transaction() as higgsboson:
    for i in higgsboson.run('match ()-[replys:Replys]->() return count(replys)'):
        print(i)
# Out:
# <Record count(replys)=32523>

# %% [markdown]
# ### 6. How many times did users in this network mention other users in their tweets?

# %%
# Question 6:
# How many times did users in this network mention other users in their tweets?
#
with session.begin_transaction() as higgsboson:
    for i in higgsboson.run('match ()-[mentions:Mentions]->() return count(mentions)'):
        print(i)
# Out:
# <Record count(mentions)=150818>

# %% [markdown]
# ### 7. How many users follow user 89805 ?

# %%
# Question 7:
# How many users follow user 89805?
#
with session.begin_transaction() as higgsboson:
    for i in higgsboson.run('match (follower)-[:Follows]->(:User{user:89805}) return count(follower)'):
        print(i)
# Out:
# <Record count(follower)=156>

# %% [markdown]
# ### 8. How many users does user 89805 follow?

# %%
# Question 8:
# How many users does user 89805 follow?
#
with session.begin_transaction() as higgsboson:
    for i in higgsboson.run('match (:User{user:89805})-[:Follows]->(user:User) return count(user)'):
        print(i)
# Out:
# <Record count(user)=171>

# %% [markdown]
# ### 9. Did user 14907 ever retweet user 89805?

# %%
# Question 9:
# Did user 14907 ever retweet user 89805?
#
# Let us call this quantity as n_x_tweets
#
with session.begin_transaction() as higgsboson:
    for i in higgsboson.run('match ({user:14907})-[n_x_tweets:Retweets]->({user:89805}) return count(n_x_tweets)'):
        print(i)
# Out:
# <Record count(n_x_tweets)=0>

# %% [markdown]
# ### 10. Did user 89805 ever retweet user 14907?

# %%
# Question 10:
# Did user 89805 ever retweet user 14907?
#
# Let us call this quantity as n_x_tweets
# This is the reverse version of Question 9 - so we can use the same code
#
with session.begin_transaction() as higgsboson:
    for i in higgsboson.run('match ({user:89805})-[n_x_tweets:Retweets]->({user:14907}) return count(n_x_tweets)'):
        print(i)
# Out:
# <Record count(n_x_tweets)=1>

# %% [markdown]
# ### 11. Find out the top 5 users with the highest number of followers?

# %%
# Question 11:
# Find out the top 5 users with the highest number of followers?
#
# We should be able to sort the number of followers per user in descending order
# and then we can limit our output to only 5
#
# To avoid confusion, let us consider this as x-y pairs 
# x being followers and y being users
#
with session.begin_transaction() as higgsboson:
    for i in higgsboson.run('match ()-[x:Follows]->(y:User) return(y), count(x) order by count(x) desc limit 5'):
        print(i)
# Out:
# <Record y=<Node id=1502 labels={'User'} properties={'user': 1503}> count(x)=51386>
# <Record y=<Node id=205 labels={'User'} properties={'user': 206}> count(x)=48414>
# <Record y=<Node id=87 labels={'User'} properties={'user': 88}> count(x)=45221>
# <Record y=<Node id=137 labels={'User'} properties={'user': 138}> count(x)=44188>
# <Record y=<Node id=1061 labels={'User'} properties={'user': 1062}> count(x)=40120>

# %% [markdown]
# ### 12. What is the total count of followers of followers of user 89805?

# %%
# Question 12:
# What is the total count of followers of followers of user 89805?
#
# The below line is going to return all users who follow 89805
# There should 156
#
with session.begin_transaction() as higgsboson:
    for i in higgsboson.run('match (follower)-[:Follows]->(:User{user:89805}) return follower'):
        print(i)
# Out:
# <Record follower=<Node id=371756 labels={'User'} properties={'user': 371757}>>
# <Record follower=<Node id=113222 labels={'User'} properties={'user': 113223}>>
# <Record follower=<Node id=51402 labels={'User'} properties={'user': 51403}>>
# <Record follower=<Node id=11904 labels={'User'} properties={'user': 11905}>>
# <Record follower=<Node id=444473 labels={'User'} properties={'user': 444474}>>
# <Record follower=<Node id=113800 labels={'User'} properties={'user': 113801}>>
# <Record follower=<Node id=93158 labels={'User'} properties={'user': 93159}>>
# <Record follower=<Node id=86367 labels={'User'} properties={'user': 86368}>>
# <Record follower=<Node id=129522 labels={'User'} properties={'user': 129523}>>
# <Record follower=<Node id=225225 labels={'User'} properties={'user': 225226}>>
# <Record follower=<Node id=177655 labels={'User'} properties={'user': 177656}>>
# <Record follower=<Node id=115059 labels={'User'} properties={'user': 115060}>>
# <Record follower=<Node id=38805 labels={'User'} properties={'user': 38806}>>
# <Record follower=<Node id=59191 labels={'User'} properties={'user': 59192}>>
# <Record follower=<Node id=206482 labels={'User'} properties={'user': 206483}>>
# <Record follower=<Node id=349170 labels={'User'} properties={'user': 349171}>>
# <Record follower=<Node id=127660 labels={'User'} properties={'user': 127661}>>
# <Record follower=<Node id=121428 labels={'User'} properties={'user': 121429}>>
# <Record follower=<Node id=46837 labels={'User'} properties={'user': 46838}>>
# <Record follower=<Node id=64611 labels={'User'} properties={'user': 64612}>>
# <Record follower=<Node id=309936 labels={'User'} properties={'user': 309937}>>
# <Record follower=<Node id=128514 labels={'User'} properties={'user': 128515}>>
# <Record follower=<Node id=51714 labels={'User'} properties={'user': 51715}>>
# <Record follower=<Node id=72328 labels={'User'} properties={'user': 72329}>>
# <Record follower=<Node id=190862 labels={'User'} properties={'user': 190863}>>
# <Record follower=<Node id=285106 labels={'User'} properties={'user': 285107}>>
# <Record follower=<Node id=11699 labels={'User'} properties={'user': 11700}>>
# <Record follower=<Node id=50970 labels={'User'} properties={'user': 50971}>>
# <Record follower=<Node id=211006 labels={'User'} properties={'user': 211007}>>
# <Record follower=<Node id=10481 labels={'User'} properties={'user': 10482}>>
# <Record follower=<Node id=41827 labels={'User'} properties={'user': 41828}>>
# <Record follower=<Node id=27488 labels={'User'} properties={'user': 27489}>>
# <Record follower=<Node id=105415 labels={'User'} properties={'user': 105416}>>
# <Record follower=<Node id=49124 labels={'User'} properties={'user': 49125}>>
# <Record follower=<Node id=93687 labels={'User'} properties={'user': 93688}>>
# <Record follower=<Node id=92780 labels={'User'} properties={'user': 92781}>>
# <Record follower=<Node id=104187 labels={'User'} properties={'user': 104188}>>
# <Record follower=<Node id=38327 labels={'User'} properties={'user': 38328}>>
# <Record follower=<Node id=156685 labels={'User'} properties={'user': 156686}>>
# <Record follower=<Node id=278584 labels={'User'} properties={'user': 278585}>>
# <Record follower=<Node id=1575 labels={'User'} properties={'user': 1576}>>
# <Record follower=<Node id=67195 labels={'User'} properties={'user': 67196}>>
# <Record follower=<Node id=64910 labels={'User'} properties={'user': 64911}>>
# <Record follower=<Node id=22848 labels={'User'} properties={'user': 22849}>>
# <Record follower=<Node id=21279 labels={'User'} properties={'user': 21280}>>
# <Record follower=<Node id=48597 labels={'User'} properties={'user': 48598}>>
# <Record follower=<Node id=50948 labels={'User'} properties={'user': 50949}>>
# <Record follower=<Node id=329360 labels={'User'} properties={'user': 329361}>>
# <Record follower=<Node id=39419 labels={'User'} properties={'user': 39420}>>
# <Record follower=<Node id=35213 labels={'User'} properties={'user': 35214}>>
# <Record follower=<Node id=6764 labels={'User'} properties={'user': 6765}>>
# <Record follower=<Node id=55492 labels={'User'} properties={'user': 55493}>>
# <Record follower=<Node id=13819 labels={'User'} properties={'user': 13820}>>
# <Record follower=<Node id=10086 labels={'User'} properties={'user': 10087}>>
# <Record follower=<Node id=3424 labels={'User'} properties={'user': 3425}>>
# <Record follower=<Node id=51168 labels={'User'} properties={'user': 51169}>>
# <Record follower=<Node id=88694 labels={'User'} properties={'user': 88695}>>
# <Record follower=<Node id=24476 labels={'User'} properties={'user': 24477}>>
# <Record follower=<Node id=5154 labels={'User'} properties={'user': 5155}>>
# <Record follower=<Node id=14489 labels={'User'} properties={'user': 14490}>>
# <Record follower=<Node id=123073 labels={'User'} properties={'user': 123074}>>
# <Record follower=<Node id=74018 labels={'User'} properties={'user': 74019}>>
# <Record follower=<Node id=240283 labels={'User'} properties={'user': 240284}>>
# <Record follower=<Node id=118355 labels={'User'} properties={'user': 118356}>>
# <Record follower=<Node id=147239 labels={'User'} properties={'user': 147240}>>
# <Record follower=<Node id=15209 labels={'User'} properties={'user': 15210}>>
# <Record follower=<Node id=17174 labels={'User'} properties={'user': 17175}>>
# <Record follower=<Node id=26090 labels={'User'} properties={'user': 26091}>>
# <Record follower=<Node id=92159 labels={'User'} properties={'user': 92160}>>
# <Record follower=<Node id=226574 labels={'User'} properties={'user': 226575}>>
# <Record follower=<Node id=325415 labels={'User'} properties={'user': 325416}>>
# <Record follower=<Node id=73100 labels={'User'} properties={'user': 73101}>>
# <Record follower=<Node id=10922 labels={'User'} properties={'user': 10923}>>
# <Record follower=<Node id=110902 labels={'User'} properties={'user': 110903}>>
# <Record follower=<Node id=29143 labels={'User'} properties={'user': 29144}>>
# <Record follower=<Node id=10467 labels={'User'} properties={'user': 10468}>>
# <Record follower=<Node id=319821 labels={'User'} properties={'user': 319822}>>
# <Record follower=<Node id=12750 labels={'User'} properties={'user': 12751}>>
# <Record follower=<Node id=35728 labels={'User'} properties={'user': 35729}>>
# <Record follower=<Node id=30321 labels={'User'} properties={'user': 30322}>>
# <Record follower=<Node id=30115 labels={'User'} properties={'user': 30116}>>
# <Record follower=<Node id=139661 labels={'User'} properties={'user': 139662}>>
# <Record follower=<Node id=51240 labels={'User'} properties={'user': 51241}>>
# <Record follower=<Node id=22554 labels={'User'} properties={'user': 22555}>>
# <Record follower=<Node id=28252 labels={'User'} properties={'user': 28253}>>
# <Record follower=<Node id=46812 labels={'User'} properties={'user': 46813}>>
# <Record follower=<Node id=79506 labels={'User'} properties={'user': 79507}>>
# <Record follower=<Node id=4367 labels={'User'} properties={'user': 4368}>>
# <Record follower=<Node id=96412 labels={'User'} properties={'user': 96413}>>
# <Record follower=<Node id=13794 labels={'User'} properties={'user': 13795}>>
# <Record follower=<Node id=13797 labels={'User'} properties={'user': 13798}>>
# <Record follower=<Node id=133886 labels={'User'} properties={'user': 133887}>>
# <Record follower=<Node id=1291 labels={'User'} properties={'user': 1292}>>
# <Record follower=<Node id=132368 labels={'User'} properties={'user': 132369}>>
# <Record follower=<Node id=66126 labels={'User'} properties={'user': 66127}>>
# <Record follower=<Node id=23955 labels={'User'} properties={'user': 23956}>>
# <Record follower=<Node id=167903 labels={'User'} properties={'user': 167904}>>
# <Record follower=<Node id=11881 labels={'User'} properties={'user': 11882}>>
# <Record follower=<Node id=29595 labels={'User'} properties={'user': 29596}>>
# <Record follower=<Node id=86352 labels={'User'} properties={'user': 86353}>>
# <Record follower=<Node id=49095 labels={'User'} properties={'user': 49096}>>
# <Record follower=<Node id=13114 labels={'User'} properties={'user': 13115}>>
# <Record follower=<Node id=11849 labels={'User'} properties={'user': 11850}>>
# <Record follower=<Node id=54264 labels={'User'} properties={'user': 54265}>>
# <Record follower=<Node id=7638 labels={'User'} properties={'user': 7639}>>
# <Record follower=<Node id=35161 labels={'User'} properties={'user': 35162}>>
# <Record follower=<Node id=15925 labels={'User'} properties={'user': 15926}>>
# <Record follower=<Node id=518 labels={'User'} properties={'user': 519}>>
# <Record follower=<Node id=81180 labels={'User'} properties={'user': 81181}>>
# <Record follower=<Node id=11997 labels={'User'} properties={'user': 11998}>>
# <Record follower=<Node id=35725 labels={'User'} properties={'user': 35726}>>
# <Record follower=<Node id=117614 labels={'User'} properties={'user': 117615}>>
# <Record follower=<Node id=26133 labels={'User'} properties={'user': 26134}>>
# <Record follower=<Node id=107541 labels={'User'} properties={'user': 107542}>>
# <Record follower=<Node id=19236 labels={'User'} properties={'user': 19237}>>
# <Record follower=<Node id=20378 labels={'User'} properties={'user': 20379}>>
# <Record follower=<Node id=15768 labels={'User'} properties={'user': 15769}>>
# <Record follower=<Node id=98986 labels={'User'} properties={'user': 98987}>>
# <Record follower=<Node id=49544 labels={'User'} properties={'user': 49545}>>
# <Record follower=<Node id=63924 labels={'User'} properties={'user': 63925}>>
# <Record follower=<Node id=28783 labels={'User'} properties={'user': 28784}>>
# <Record follower=<Node id=33069 labels={'User'} properties={'user': 33070}>>
# <Record follower=<Node id=501 labels={'User'} properties={'user': 502}>>
# <Record follower=<Node id=13767 labels={'User'} properties={'user': 13768}>>
# <Record follower=<Node id=35722 labels={'User'} properties={'user': 35723}>>
# <Record follower=<Node id=23939 labels={'User'} properties={'user': 23940}>>
# <Record follower=<Node id=168652 labels={'User'} properties={'user': 168653}>>
# <Record follower=<Node id=72303 labels={'User'} properties={'user': 72304}>>
# <Record follower=<Node id=49394 labels={'User'} properties={'user': 49395}>>
# <Record follower=<Node id=13087 labels={'User'} properties={'user': 13088}>>
# <Record follower=<Node id=4344 labels={'User'} properties={'user': 4345}>>
# <Record follower=<Node id=20492 labels={'User'} properties={'user': 20493}>>
# <Record follower=<Node id=50890 labels={'User'} properties={'user': 50891}>>
# <Record follower=<Node id=5225 labels={'User'} properties={'user': 5226}>>
# <Record follower=<Node id=30261 labels={'User'} properties={'user': 30262}>>
# <Record follower=<Node id=467 labels={'User'} properties={'user': 468}>>
# <Record follower=<Node id=100939 labels={'User'} properties={'user': 100940}>>
# <Record follower=<Node id=27615 labels={'User'} properties={'user': 27616}>>
# <Record follower=<Node id=14165 labels={'User'} properties={'user': 14166}>>
# <Record follower=<Node id=87 labels={'User'} properties={'user': 88}>>
# <Record follower=<Node id=11266 labels={'User'} properties={'user': 11267}>>
# <Record follower=<Node id=43148 labels={'User'} properties={'user': 43149}>>
# <Record follower=<Node id=56425 labels={'User'} properties={'user': 56426}>>
# <Record follower=<Node id=27558 labels={'User'} properties={'user': 27559}>>
# <Record follower=<Node id=27146 labels={'User'} properties={'user': 27147}>>
# <Record follower=<Node id=110599 labels={'User'} properties={'user': 110600}>>
# <Record follower=<Node id=19202 labels={'User'} properties={'user': 19203}>>
# <Record follower=<Node id=14749 labels={'User'} properties={'user': 14750}>>
# <Record follower=<Node id=50218 labels={'User'} properties={'user': 50219}>>
# <Record follower=<Node id=126955 labels={'User'} properties={'user': 126956}>>
# <Record follower=<Node id=53574 labels={'User'} properties={'user': 53575}>>
# <Record follower=<Node id=115750 labels={'User'} properties={'user': 115751}>>
# <Record follower=<Node id=1477 labels={'User'} properties={'user': 1478}>>
# <Record follower=<Node id=21908 labels={'User'} properties={'user': 21909}>>
# <Record follower=<Node id=22449 labels={'User'} properties={'user': 22450}>>
# <Record follower=<Node id=89801 labels={'User'} properties={'user': 89802}>>

# %%
# Now let us find the total number of followers of 89805 followers
#
with session.begin_transaction() as higgsboson:
    for i in higgsboson.run('match (who_follows_89805_followers)-[:Follows]-()-[:Follows]->({user:89805}) return count(who_follows_89805_followers)'):
        print(i)
# Out:
# <Record count(who_follows_89805_followers)=172520>
